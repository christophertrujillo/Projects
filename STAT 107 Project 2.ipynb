# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("/Users/chris/OneDrive/Desktop/stat107/ct18/project2/CDL 2023_OVR_ Master Leaderboard.csv")
df
# Out:
#          Player  CTL Kills Per 10 ..   F13  HP # of Maps  HP DMG Per 10 ..  \
# 0       Cellium                 17.6  1.29             7              2606
# 1          Afro                 19.6  1.25             8              2668
# 2         Scump                 18.2  1.11             7              2710
# 3       Scrappy                 19.7  1.22             8              2819
# 4         HyDra                 22.3  1.24             6              2643
# 5          Asim                 19.3  1.15             7              2940
# 6        Standy                 18.3  1.23             8              2444
# 7           Sib                 20.7  1.16             8              3007
# 8     Owakening                 14.7  0.84             8              2919
# 9        Attach                 16.1  1.17             8              2487
# 10         Temp                 17.6  1.04             7              2901
# ...

# %% [markdown]
# #Created a dataframe with just the players that have an overall KD greater than or equal to 1.

# %%
topkd = df[(df["Overall KD"] >= 1)]
topkd
# Out:
#          Player  CTL Kills Per 10 ..   F13  HP # of Maps  HP DMG Per 10 ..  \
# 0       Cellium                 17.6  1.29             7              2606
# 1          Afro                 19.6  1.25             8              2668
# 2         Scump                 18.2  1.11             7              2710
# 3       Scrappy                 19.7  1.22             8              2819
# 4         HyDra                 22.3  1.24             6              2643
# 5          Asim                 19.3  1.15             7              2940
# 6        Standy                 18.3  1.23             8              2444
# 7           Sib                 20.7  1.16             8              3007
# 8     Owakening                 14.7  0.84             8              2919
# 9        Attach                 16.1  1.17             8              2487
# 10         Temp                 17.6  1.04             7              2901
# ...

# %%
topkd.plot.scatter(x = "Player", y= "Overall KD")
# Out:
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Player', ylabel='Overall KD'>

# %% [markdown]
# #Found that the graph makes sense in relation to the data presented in the table above.

# %%
topkd.plot.scatter(x = "Player", y= "HP Kill Death R..")
# Out:
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Player', ylabel='HP Kill Death R..'>

# %%
df.plot.scatter(x = "Player", y= "HP Kill Death R..")
# Out:
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Player', ylabel='HP Kill Death R..'>

# %% [markdown]
# *When comparing the relationship between players and HP KD, we see that amongst all players in the data frame the relationship is clearly negative, however, when examing players with a kd higher than 1, we see that the relationship isn't as clear.*

# %%
topkd.plot.scatter(x = "Player", y= "SnD Kill Death R..")
# Out:
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Player', ylabel='SnD Kill Death R..'>

# %%
df.plot.scatter(x = "Player", y= "SnD Kill Death R..")
# Out:
# c:\Users\chris\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Player', ylabel='SnD Kill Death R..'>

# %% [markdown]
# Likewise, when comparing the relationship between the players and S&D KD we see that amongst all players the relationship is clearly negative, whereas amongst those in topkd, the relationship is even less clear than in the HP KD.

# %%
sns.lmplot (x = "HP DMG Per 10 ..", y= "HP Kill Death R..", data= topkd)

# %% [markdown]
# In the above graph I ran a linear regression to predict the HP KD of players based on the amount of damage they produce every 10 minutes of a match.

# %%
sns.lmplot (x= "HP Hill Time", y= "HP Kill Death R..", data= topkd)

# %%
sns.lmplot (x= "SnD 1st Bloods", y= "SnD Kill Death R..", data= topkd)
